# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def load_image():
    blank_image = np.zeros((600,800))
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(blank_image,text='ARAVIND',org=(50,300),fontFace=font,fontScale = 5,color=(255,255,255),thickness=15,lineType=cv2.LINE_AA)
    return blank_image

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')
    plt.show()

# %%
img=load_image()

# %%
display_img(img)

# %%
kernel=np.ones((5,5),dtype=np.uint8)

# %%
erosion = cv2.erode(img,kernel,iterations = 2)

# %%
display_img(erosion)

# %%
dilution=cv2.dilate(img,kernel,iterations=2)

# %%
display_img(dilution)
